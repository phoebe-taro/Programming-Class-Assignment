# %% [markdown]
# ##2.3

# %% [markdown]
# ###ex5

# %%
2**120
# Out:
# 1329227995784915872903807060280344576

# %% [markdown]
# ###ex6

# %%
128%39
# Out:
# 11

# %% [markdown]
# ###ex7

# %%
'kitty'<'kitten'
# Out:
# False

# %%
ord('y')
# Out:
# 121

# %%
ord('e')
# Out:
# 101

# %% [markdown]
# 因為y的ASCII碼為121，e的ASCII碼為101，121>101所以為False

# %% [markdown]
# ##2.4

# %% [markdown]
# ###ex10

# %% [markdown]
# ####a

# %%
x=5 ; x+=2 ; x
# Out:
# 7

# %% [markdown]
# ####b

# %%
x=7 ; x*=3 ; x
# Out:
# 21

# %% [markdown]
# ####C

# %%
x=3; x**= 4 ; x
# Out:
# 81

# %% [markdown]
# ###ex11

# %% [markdown]
# ####a

# %%
6+3**2*4
# Out:
# 42

# %% [markdown]
# ####b

# %%
15/3+4*4/2
# Out:
# 13.0

# %% [markdown]
# ####c

# %%
6>2+5
# Out:
# False

# %% [markdown]
# ###ex12

# %%
 #因為+的優先順序高於not，此時'piggy'為字串，ture為布林值無法相加出現語法錯誤

# %%
True +(not 'piggy')
# Out:
# 1

# %%
(not 'piggy') + True
# Out:
# 1

# %% [markdown]
# 3
# ##2.5

# %% [markdown]
# ###ex13

# %% [markdown]
# ####a

# %%
2+True #隱式
# Out:
# 3

# %% [markdown]
# ####b

# %%
6+int(17.4) #顯式
# Out:
# 23

# %% [markdown]
# ####c

# %%
21+6.5 #隱式
# Out:
# 27.5

# %% [markdown]
# ####d

# %%
str(2) + 'piggy' #顯式
# Out:
# '2piggy'

# %% [markdown]
# ###ex14

# %% [markdown]
# ####a

# %%
eval('66+18')
# Out:
# 84

# %% [markdown]
# ####b

# %%
eval('6**2+3*(7-1)')
# Out:
# 54

# %% [markdown]
# ####c

# %%
eval("int('2020')")
# Out:
# 2020

# %% [markdown]
# ##2.6

# %% [markdown]
# ###ex15

# %%
bin(1024)
# Out:
# '0b10000000000'

# %%
oct(1024)
# Out:
# '0o2000'

# %%
hex(1024)
# Out:
# '0x400'

# %% [markdown]
# ###ex16

# %%
bin(0o65416)
# Out:
# '0b110101100001110'

# %%
int(0o65416)
# Out:
# 27406

# %%
hex(0o65416)
# Out:
# '0x6b0e'

# %% [markdown]
# ###ex17

# %%
oct(0b1001001)
# Out:
# '0o111'

# %%
int(0b1001001)
# Out:
# 73

# %%
hex(0b1001001)
# Out:
# '0x49'

# %% [markdown]
# ##2.7

# %% [markdown]
# ###ex18

# %% [markdown]
# ####a

# %%
print("'Holliday'")
# Out:
# 'Holliday'

# %% [markdown]
# ####b

# %%
print('"You may say I\'m a dreamer"')
# Out:
# "You may say I'm a dreamer"

# %% [markdown]
# ####c

# %%
print('A back slash \\ sign.')
# Out:
# A back slash \ sign.

# %% [markdown]
# ####d

# %%
print("'''\\n represents a new line character'''")
# Out:
# '''\n represents a new line character'''

# %% [markdown]
# ###ex19

# %%
a = 12670 ; b = 12.344

# %% [markdown]
# ####a

# %%
print(f'a={a:7d}, b={b:6.2f}')
# Out:
# a=  12670, b= 12.34

# %% [markdown]
# ####b

# %%
print(f'a={a:+7d}, b={b:06.2f}')
# Out:
# a= +12670, b=012.34

# %% [markdown]
# ####c

# %%
print(f'a={a:+,d}, b={b:06.1f}')
# Out:
# a=+12,670, b=0012.3

# %% [markdown]
# ####d

# %%
print(f'a={a:07,d}, b={b:+6.0f}')
# Out:
# a=012,670, b=   +12

# %% [markdown]
# ####e

# %%
print(f'a={{{a}}}, b=\'{b:4.0f}\'')
# Out:
# a={12670}, b='  12'

# %% [markdown]
# ###ex20

# %%
eval(input('輸入一個整數：') + '**2')
# Out:
# 輸入一個整數：3
# 9

# %% [markdown]
# ###ex21

# %%
num= int(input('輸入一個整數：')); bin(num)
# Out:
# 輸入一個整數：3
# '0b11'

# %% [markdown]
# ##3.1

# %% [markdown]
# ###ex1

# %%
max(12, 81, 93,27)
# Out:
# 93

# %%
min(12, 81, 93,27)
# Out:
# 12

# %% [markdown]
# ###ex2

# %%
pow(2,1024)
# Out:
# 

# %% [markdown]
# ###ex3

# %%
import math

# %% [markdown]
# ####b

# %%
math.ceil(pow(6.3,2)-0.5)
# Out:
# 40

# %% [markdown]
# ####c

# %%
math.floor(math.cos(pow(0.5,2))+math.sqrt(2))
# Out:
# 2

# %% [markdown]
# ####d

# %%
math.gcd(6,8,12)
# Out:
# 2

# %% [markdown]
# ####e

# %%
math.inf - 2 * math.inf
# Out:
# nan

# %% [markdown]
# ####f

# %%
pow(3,0.5)
# Out:
# 1.7320508075688772

# %% [markdown]
# ###ex4

# %%
math.radians(105)
# Out:
# 1.8325957145940461

# %% [markdown]
# ###ex5

# %%
4/3 * math.pi * pow(3.2,3)   #體積
# Out:
# 137.25827743044047

# %%
4 * math.pi * pow(3.2,2)    #表面積
# Out:
# 128.67963509103794

# %% [markdown]
# ##3.2

# %% [markdown]
# ###ex6

# %%
import random

# %% [markdown]
# ####a

# %%
random.random()
# Out:
# 0.220461764746674

# %% [markdown]
# ####b

# %%
random.sample('Significant',3)
# Out:
# ['i', 'S', 'f']

# %% [markdown]
# ####c

# %%
random.randint(1,6)
# Out:
# 3

# %% [markdown]
# ####d

# %%
random.randrange(2,11,2)
# Out:
# 4

# %% [markdown]
# ####e

# %%
random.uniform(-1,1)
# Out:
# 0.6295491738248882

# %% [markdown]
# ###ex7

# %%
random.seed(37)

# %% [markdown]
# ####a

# %%
random.randint(1,100)
# Out:
# 88

# %% [markdown]
# ####b

# %%
random.sample('Halloween',4)
# Out:
# ['a', 'H', 'w', 'l']

# %% [markdown]
# ####c

# %%
random.choices([12,38,54,64,77,29],k=2)
# Out:
# [54, 77]

# %% [markdown]
# ####d

# %%
mylist=[2,3,5,8,9,11]
random.shuffle(mylist)
mylist
# Out:
# [2, 9, 3, 5, 8, 11]

# %% [markdown]
# ##3.3

# %% [markdown]
# ###ex10

# %%
'*^_^*' *10
# Out:
# '*^_^**^_^**^_^**^_^**^_^**^_^**^_^**^_^**^_^**^_^*'

# %% [markdown]
# ###ex11

# %%
s1 = 'Have a nice day'

# %% [markdown]
# ####a

# %%
s1[7:11]
# Out:
# 'nice'

# %% [markdown]
# ####b

# %%
'day'in s1
# Out:
# True

# %% [markdown]
# ####c

# %%
s1[-1]
# Out:
# 'y'

# %% [markdown]
# ####d

# %%
max(s1)
# Out:
# 'y'

# %% [markdown]
# ##3.4

# %% [markdown]
# ###ex12

# %%
s1='it is never too late to learn'

# %% [markdown]
# ####a

# %%
s1.title()
# Out:
# 'It Is Never Too Late To Learn'

# %% [markdown]
# ####b

# %%
s1.capitalize()
# Out:
# 'It is never too late to learn'

# %% [markdown]
# ####c

# %%
s1.isalpha()
# Out:
# False

# %% [markdown]
# ####d

# %%
s1.count('e')
# Out:
# 4

# %% [markdown]
# ####e

# %%
 s1.replace('never ','')
# Out:
# 'it is too late to learn'

# %% [markdown]
# ####f

# %%
s1.replace('late','LATE')
# Out:
# 'it is never too LATE to learn'

# %% [markdown]
# ###ex13

# %%
 'cats and dogs'.title().replace(' ','')
# Out:
# 'CatsAndDogs'

# %% [markdown]
# ###ex14

# %%
'*^_^* Python *w_w*'.strip('*^_^* *w_w*')
# Out:
# 'Python'

# %% [markdown]
# ###ex15

# %%
 '  Peggy Chen  '.strip()
# Out:
# 'Peggy Chen'

# %% [markdown]
# ###ex16

# %%
a=16 ; b=21.5639

# %% [markdown]
# ####a

# %%
 print('a={:8.2f}, b={:8.3f}'.format(a,b))
# Out:
# a=   16.00, b=  21.564

# %% [markdown]
# ####b

# %%
print('a={:8d}, b={:08.3f}'.format(a,b))
# Out:
# a=      16, b=0021.564

# %% [markdown]
# ####c

# %%
print('a={:<+8.1f}, b={:<+8.3f}'.format(a,b))
# Out:
# a=+16.0   , b=+21.564

# %% [markdown]
# ####d

# %%
print('a={:#8x}, b={:8d}'.format(a,math.ceil(b)))
# Out:
# a=    0x10, b=      22

# %% [markdown]
# ####e

# %%
print('a={:#8o}, b={:+08.2f}'.format(a,b))
# Out:
# a=    0o20, b=+0021.56

# %% [markdown]
# ####f

# %%
print('a={{{:#6o}}}, b={{{:6.2f}}}'.format(a,b))
# Out:
# a={  0o20}, b={ 21.56}

# %% [markdown]
# ####g

# %%
print("a=  '{:#o}', b={:8.5f}".format(a,b))
# Out:
# a=  '0o20', b=21.56390

# %% [markdown]
# ####h

# %%
print('a={{\'{:=#o}\'}}, b=\'{{{:5.2f}}}\''.format(a,b))
# Out:
# a={'0o20'}, b='{21.56}'
