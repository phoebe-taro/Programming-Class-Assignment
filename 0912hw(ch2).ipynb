# %% [markdown]
# ##2.1

# %% [markdown]
# ###ex1

# %% [markdown]
# a. str\
# b. bool\
# c. int\
# d. float\
# e. bool\
# f. float\
# g. float\
# h. float\
# i. int\
# j. int\
# k. complex\
# l. int\
# m. str

# %% [markdown]
# ###ex2

# %% [markdown]
# ####a.

# %%
0xa0ff
# Out:
# 41215

# %%
0x121ab
# Out:
# 74155

# %%
0xacd123
# Out:
# 11325731

# %% [markdown]
# ####b.

# %%
0o7231
# Out:
# 3737

# %%
0o754
# Out:
# 492

# %%
0o567
# Out:
# 375

# %% [markdown]
# ####c.

# %%
0b11001010
# Out:
# 202

# %%
0b1001001
# Out:
# 73

# %%
0b110101000100010110
# Out:
# 217366

# %% [markdown]
# ##2.2

# %% [markdown]
# ###ex3

# %%
num=12; num=12+7.2; num
# Out:
# 19.2

# %%
type(num)
# Out:
# float

# %% [markdown]
# ### ex4

# %% [markdown]
# (a) MAX_NUM (d) ID
